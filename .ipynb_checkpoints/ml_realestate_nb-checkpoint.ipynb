# %% [markdown]
# # Project to Predict real-estate price

# %%
import pandas as pd

# %%
housing = pd.read_csv("data.csv")

# %% [markdown]
# housing is DataFrame --- head() finction displays top 5 data rows --- info() total entries [we can check missing values]

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4  0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
#
#    PTRATIO         B  LSTAT     MEDV
# 0       15.3  396.90      4.98  24.0
# 1       17.8  396.90      9.14  21.6
# 2       18.7  394.63      2.94  33.4
# 3       18.7  396.90      5.33  36.2
# 4       18.7  394.12      5.21  28.7

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CRIM       505 non-null    object
#  1   ZN         504 non-null    float64
#  2   INDUS      505 non-null    float64
#  3   CHAS       505 non-null    int64
#  4   NOX        505 non-null    float64
#  5   RM         505 non-null    float64
#  6   AGE        505 non-null    float64
#  7   DIS        505 non-null    float64
#  8   RAD        505 non-null    int64
#  9   TAX        505 non-null    int64
#  10  PTRATIO    505 non-null    float64
#  11  B          505 non-null    float64
#  12  LSTAT      505 non-null    float64
#  13  MEDV       505 non-null    float64
# dtypes: float64(10), int64(3), object(1)
# memory usage: 55.4+ KB

# %%
housing['CHAS'].value_counts()
# Out:
# 0    470
# 1     35
# Name: CHAS, dtype: int64

# %% [markdown]
# After exe describe()
#
# count = ignores null values
# mean= average
# std=standard Deviation
# min=minimum values
# max=maximum values

# %%
housing.describe()
# Out:
#                ZN       INDUS        CHAS         NOX          RM         AGE  \
# count  504.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean    11.210317   11.144832    0.069307    0.554865    6.282851   68.589703
# std     23.026077    6.864761    0.254227    0.115930    0.702167   28.174802
# min      0.000000    0.460000    0.000000    0.385000    3.561000    2.900000
# 25%      0.000000    5.190000    0.000000    0.449000    5.885000   45.000000
# 50%      0.000000    9.690000    0.000000    0.538000    6.208000   77.700000
# 75%     12.500000   18.100000    0.000000    0.624000    6.619000   94.100000
# max     95.000000   27.740000    1.000000    0.871000    8.780000  100.000000
#
#               DIS         RAD         TAX   PTRATIO             B    LSTAT     \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean     3.792722    9.564356  408.566337   18.456832  356.602436   12.670139
# std      2.107150    8.709391  168.541326    2.166895   91.371169    7.137795
# min      1.129600    1.000000  187.000000   12.600000    0.320000    1.730000
# 25%      2.100000    4.000000  279.000000   17.400000  375.330000    7.010000
# 50%      3.199200    5.000000  330.000000   19.100000  391.430000   11.380000
# 75%      5.211900   24.000000  666.000000   20.200000  396.230000   16.960000
# max     12.126500   24.000000  711.000000   22.000000  396.900000   37.970000
#
#              MEDV
# count  505.000000
# mean    22.508713
# std      9.190225
# min      5.000000
# 25%     17.000000
# 50%     21.200000
# 75%     25.000000
# max     50.000000

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
housing.hist(bins=50,figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f69272e7780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6926fd94a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6926fa8710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6926fa4978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69270f8be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6926f5de48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6926ec80f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6926ef6320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f6926ef6390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6927173828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6927115a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6927128cf8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f692701ef60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6927063208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69271b1470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f692725f6d8>]],
#       dtype=object)
